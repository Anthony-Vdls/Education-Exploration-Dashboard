# %% [markdown]
# # Lab 4.3 Mini Project Dashboard Desgin
# ---

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv('epcg23.csv')
df.shape
# Out:
# (94606, 548)

# %%
df.isnull().sum()
# Out:
# ACADV      0
# ACCAR      0
# ACCCEP     0
# ACCHG      0
# ACDRG      0
#           ..
# WTROPPS    0
# WTROT      0
# WTRPERS    0
# WTRSKL     0
# WTSURVY    0
# Length: 548, dtype: int64

# %%
df.dtypes
# Out:
# ACADV       object
# ACCAR       object
# ACCCEP      object
# ACCHG       object
# ACDRG       object
#             ...
# WTROPPS     object
# WTROT       object
# WTRPERS     object
# WTRSKL      object
# WTSURVY    float64
# Length: 548, dtype: object

# %%
dfcopy = df.copy()
